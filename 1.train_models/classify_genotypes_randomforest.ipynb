# %% [markdown]
# # Classify WT and Null Genotypes Random Forest
# Plates 3, 3p, and 5 are used in all splits to classify genotypes either (WT or Null)
# The feature selected data is used in all data splits.
# Pre-evaluation metrics are stored from all splits and these plates.
# This notebook is a Random Forest version of the original classifier.

# %%
import pathlib
import random
import warnings
from collections import defaultdict

import numpy as np
import pandas as pd
from joblib import dump
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder

# %%
MODEL_ID = "randomforest"
ROLE = "train"

import logging
from datetime import datetime
import pathlib

# ============================================
# 1) Choose a RUN_ID
# ============================================
RUN_ID = datetime.now().strftime("%m_%d_%H_%M")

RUN_ID = "12_08_16_45"
ANALYSIS_TYPE = "train"


def setup_logger(
    run_id: str,
    model_id: str,
    role: str,
    log_dir: str = "logs",
    analysis_type: str = ANALYSIS_TYPE,
) -> logging.Logger:
    """
    Create a logger that writes to both stdout and a log file.

    - Logger name:  "<analysis_type>_<run_id>_<model_id>_<role>"
    - Log file:     "log_<analysis_type>_<run_id>_<model_id>.log" in `log_dir`
      (shared by all notebooks for the same model & run & analysis_type).
    """
    log_path = pathlib.Path(log_dir)
    log_path.mkdir(exist_ok=True)

    logger_name = f"{analysis_type}_{run_id}_{model_id}_{role}"
    logger = logging.getLogger(logger_name)
    logger.setLevel(logging.INFO)
    logger.propagate = False  # don't duplicate logs to root logger

    # Avoid adding handlers multiple times if the cell is re-run
    if not logger.handlers:
        # Common formatter for both handlers
        formatter = logging.Formatter(
            fmt="%(asctime)s [%(name)s] %(levelname)s: %(message)s",
            datefmt="%Y-%m-%dT%H:%M:%S",
        )

        # Stream handler (stdout)
        stream_handler = logging.StreamHandler()
        stream_handler.setLevel(logging.INFO)
        stream_handler.setFormatter(formatter)
        logger.addHandler(stream_handler)

        # File handler (one file per analysis_type + run_id + model_id)
        log_file = log_path / f"log_{analysis_type}_{run_id}_{model_id}.log"
        file_handler = logging.FileHandler(log_file)
        file_handler.setLevel(logging.INFO)
        file_handler.setFormatter(formatter)
        logger.addHandler(file_handler)

    return logger



logger = setup_logger(RUN_ID, MODEL_ID, ROLE)
logger.info("Initialized logger.")
# Out:
# 2025-12-06T23:38:59 [train_12_08_16_45_randomforest_train] INFO: Initialized logger.

# %% [markdown]
# ## Find the root of the git repo on the host system

# %%
# Get the current working directory
cwd = pathlib.Path.cwd()

if (cwd / ".git").is_dir():
    root_dir = cwd

else:
    root_dir = None
    for parent in cwd.parents:
        if (parent / ".git").is_dir():
            root_dir = parent
            break

# Check if a Git root directory was found
if root_dir is None:
    raise FileNotFoundError("No Git root directory found.")

# %% [markdown]
# ## Define paths

# %% [markdown]
# ### Input

# %%
# OPTIONAL: If the data (within the cell painting directory) is stored in a different location, add location here
repo_dir = pathlib.Path(
    "/Users/marktalbot/Documents/VC Studio Homework Folders/HighRisk/nf1_schwann_cell_painting_data"
)

# Set data level
data_level = "cleaned"

# Main directory path (converted or cleaned data)
if data_level == "cleaned":
    data_dir = pathlib.Path(
        repo_dir / "3.processing_features/data/single_cell_profiles/cleaned_sc_profiles"
    )
else:
    data_dir = pathlib.Path(
        repo_dir / "3.processing_features/data/single_cell_profiles"
    )

plate3df_path = pathlib.Path(data_dir / "Plate_3_sc_feature_selected.parquet").resolve(
    strict=True
)
plate3pdf_path = pathlib.Path(
    data_dir / "Plate_3_prime_sc_feature_selected.parquet"
).resolve(strict=True)
plate5df_path = pathlib.Path(data_dir / "Plate_5_sc_feature_selected.parquet").resolve(
    strict=True
)

plate3df = pd.read_parquet(plate3df_path)
plate3pdf = pd.read_parquet(plate3pdf_path)
plate5df = pd.read_parquet(plate5df_path)

logger.info("Number of single-cells total per plate:")
logger.info(f"Plate 3: {plate3df.shape[0]}")
logger.info(f"Plate 3 prime: {plate3pdf.shape[0]}")
logger.info(f"Plate 5: {plate5df.shape[0]}")

# Set the seed
rng = np.random.default_rng(0)
# Out:
# 2025-12-06T23:39:06 [train_12_08_16_45_randomforest_train] INFO: Number of single-cells total per plate:
# 2025-12-06T23:39:06 [train_12_08_16_45_randomforest_train] INFO: Plate 3: 10206
# 2025-12-06T23:39:06 [train_12_08_16_45_randomforest_train] INFO: Plate 3 prime: 5126
# 2025-12-06T23:39:06 [train_12_08_16_45_randomforest_train] INFO: Plate 5: 5348

# %% [markdown]
# ### Outputs

# %%
data_path = pathlib.Path("data_randomforest")
data_path.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Splitting and Processing
# Functions to split and process data

# %%
gene_column = "Metadata_genotype"


def down_sample_by_genotype(_df):
    """
    Return an equal number of cells from each genotype.
    The number of cells in a genotype is the minimum number of cells from all genotypes.

    Parameters
    ----------
    _df: Pandas Dataframe
        The data to be downsampled by the gene_column column.

    Returns
    -------
    The dataframe down-sampled by genotype.
    """

    min_gene = _df[gene_column].value_counts().min()
    return _df.groupby(gene_column, group_keys=False).apply(
        lambda x: x.sample(n=min_gene, random_state=0)
    )


def process_plates(_df):
    """
    Drop rows with nans from the single cell data and remove HET cells.

    Parameters
    ----------
    _df: Pandas Dataframe
        Uncleaned plate data with nans and HET cells to be removed. Contains the column "Metadata_genotype".

    Returns
    -------
    _df: Pandas Dataframe
        Cleaned single cell data by removing nans and HET cells.
    """

    _df.dropna(inplace=True)
    _df = _df.loc[_df[gene_column] != "HET"]
    return _df


def shuffle_data(_X):
    """
    Shuffle the columns of the input dataframe independently.

    Parameters
    ----------
    _X: Pandas Dataframe
        Input feature data for shuffling the columns.
    """

    for column in _X.columns:
        _X[column] = rng.permutation(_X[column])


def store_pre_evaluation_data(_X, _y, _metadata, _datasplit):
    """
    Store model data to evaluate performance.

    Parameters
    ----------
    _X: pandas.DataFrame
        Feature matrix.
    _y: array-like
        True labels.
    _metadata: pandas.DataFrame
        Metadata (one row per sample) to carry through.
    _datasplit: str
        Name of the datasplit (e.g., 'train', 'val', 'test', 'shuffled_*').
    """
    # `model` is the currently trained classifier (either CV fold or final model)
    eval_data[f"probability_{probability_class}"].extend(
        model.predict_proba(_X)[:, 1].tolist()
    )
    eval_data["datasplit"].extend([_datasplit] * _X.shape[0])
    eval_data["predicted_genotype"].extend(model.predict(_X).tolist())
    eval_data["true_genotype"].extend(_y.tolist())
    for meta_col in _metadata.columns:
        eval_data[meta_col].extend(_metadata[meta_col].tolist())

# %% [markdown]
# ## Split and process plates

# %%
def create_splits(_wells, _plate):
    """
    Create data splits for model training. The splits are rest (train and validation) and test.

    Parameters
    ----------
    _wells: List(String)
        The well names from which single cells will be used in the test set.

    _plate: Pandas Dataframe
        Single cell data from one of the plate's containing a "Metadata_Well" column.

    Returns
    -------
    Dataframes of the split single cell data.
    """

    return (
        _plate[~_plate["Metadata_Well"].isin(_wells)],
        _plate[_plate["Metadata_Well"].isin(_wells)],
    )

# %%
plate3df = process_plates(plate3df)
p3_wells = ["C11", "E11", "C3", "F3"]
rest3df, test3df = create_splits(p3_wells, plate3df)
rest3df, test3df = down_sample_by_genotype(rest3df), down_sample_by_genotype(test3df)

plate3pdf = process_plates(plate3pdf)
p3p_wells = ["F11", "G11", "C3", "F3"]
rest3pdf, test3pdf = create_splits(p3p_wells, plate3pdf)
rest3pdf, test3pdf = down_sample_by_genotype(rest3pdf), down_sample_by_genotype(
    test3pdf
)

plate5df = process_plates(plate5df)
p5_wells = ["C9", "E11", "E3", "G3"]
rest5df, test5df = create_splits(p5_wells, plate5df)
rest5df, test5df = down_sample_by_genotype(rest5df), down_sample_by_genotype(test5df)

# %% [markdown]
# ## Combine plate columns across each data split

# %%
# Columns common to all plates
plate_cols = list(
    set(plate5df.columns) & set(plate3df.columns) & set(plate3pdf.columns)
)

restdf = pd.concat(
    [rest3df[plate_cols], rest3pdf[plate_cols], rest5df[plate_cols]], ignore_index=True
).reset_index(drop=True)

testdf = pd.concat(
    [test3df[plate_cols], test3pdf[plate_cols], test5df[plate_cols]], ignore_index=True
).reset_index(drop=True)

# %% [markdown]
# ## Encode genotypes and extract feature data

# %%
meta_cols = testdf.filter(like="Metadata").columns
feat_cols = testdf.drop(columns=meta_cols).columns

# %%
le = LabelEncoder()

y = le.fit_transform(restdf["Metadata_genotype"])
X = restdf.drop(columns=meta_cols)

y_test = le.fit_transform(testdf["Metadata_genotype"])
X_test = testdf.drop(columns=meta_cols)

# Class for saving probabilities
probability_class = le.inverse_transform([1])[0]

# %% [markdown]
# # Train Models

# %% [markdown]
# ## Specify parameters for training

# %%
import numpy as np
from datetime import datetime
import time

# Base Random Forest parameters (not searched)
rf_params = {
    "random_state": 0,
    "n_jobs": -1,
    "class_weight": "balanced",  # handle class imbalance
}

# Refined search space centered around your previous best:
# best_hp ≈ {'n_estimators': 400, 'max_depth': 40, 'min_samples_leaf': 1, 'max_features': 'sqrt'}
param_choices = {
    "n_estimators": [300, 600, 900],     # allow more trees than before
    "max_depth": [20, 40, 60, None],     # include deeper / unbounded trees
    "min_samples_leaf": [1, 2, 4],       # finer control near 1
    "max_features": ["sqrt", "log2"],    # good defaults for RF
}

# Target *total* number of hyperparameter configurations / trials
rand_iter = 100

# Number of CV folds
n_splits = 5     # keep reasonable for runtime

# Track best performance (using ROC AUC)
best_acc = -np.inf   # best mean CV AUC
best_hp = None
best_eval_data = None

# %% [markdown]
# ## Hyperparameter search

# %%
from collections import defaultdict
import os
import optuna
from optuna.trial import TrialState
from sklearn.metrics import (
    roc_auc_score,
    accuracy_score,
    recall_score,
    precision_score,
)

# Ensure tuning directory exists (relative to 1.train_models/)
os.makedirs("tuning", exist_ok=True)

# Hyperparameter search for Random Forest (with timing logs, using ROC AUC)
overall_start = time.time()

# Create/load persistent Optuna study
study = optuna.create_study(
    study_name="rf_cv",
    direction="maximize",
    storage="sqlite:///tuning/optuna_rf.sqlite3",
    load_if_exists=True,
)

# How many trials have already successfully finished?
completed_trials = [t for t in study.trials if t.state == TrialState.COMPLETE]
n_complete = len(completed_trials)

# Initialize best from existing study, if any
if n_complete > 0:
    best_trial_so_far = study.best_trial
    best_acc = float(best_trial_so_far.value)  # best mean CV AUC so far
    best_hp = best_trial_so_far.params.copy()
else:
    best_acc = -np.inf
    best_hp = None

# Decide how many *new* trials to run this time
n_to_run = max(0, rand_iter - n_complete)

logger.info(
    f"{datetime.now().isoformat(timespec='seconds')} "
    f"[INFO] Loaded Optuna study 'rf_cv' with "
    f"{len(study.trials)} total trials ({n_complete} completed). "
    f"Target total trials = {rand_iter}. "
    f"Running {n_to_run} new trials in this session."
)

for i in range(n_to_run):
    trial = study.ask()

    # Draw hyperparameters from your discrete search space
    rparams = {
        "n_estimators": trial.suggest_categorical(
            "n_estimators", param_choices["n_estimators"]
        ),
        "max_depth": trial.suggest_categorical(
            "max_depth", param_choices["max_depth"]
        ),
        "min_samples_leaf": trial.suggest_categorical(
            "min_samples_leaf", param_choices["min_samples_leaf"]
        ),
        "max_features": trial.suggest_categorical(
            "max_features", param_choices["max_features"]
        ),
    }

    # Global index for logging (across reruns)
    global_idx = n_complete + i  # 0-based index among desired trials

    iter_start = time.time()

    # Log which hyperparameters we're trying this iteration
    logger.info(
        f"{datetime.now().isoformat(timespec='seconds')} "
        f"[INFO] Iteration {global_idx + 1}/{rand_iter}: "
        f"Optuna trial {trial.number}, params={rparams}"
    )

    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=0)

    # Combine fixed RF params with the sampled hyperparameters
    comb_params = rf_params | rparams

    # Reset eval data for this hyperparameter setting
    eval_data = defaultdict(list)

    # Per-fold metric containers
    fold_aucs = []
    fold_accs = []
    fold_rec_null = []
    fold_rec_wt = []
    fold_prec_null = []

    # Loop through the folds
    for fold, (train_index, val_index) in enumerate(skf.split(X, y), start=1):
        fold_start = time.time()

        X_train, X_val = X.iloc[train_index], X.iloc[val_index]
        y_train, y_val = y[train_index], y[val_index]

        # Create a shuffled version of the validation features for the null model
        X_val_shuf = X_val.copy()
        shuffle_data(X_val_shuf)

        # Train RF model on this fold
        model = RandomForestClassifier(**comb_params)
        model.fit(X_train, y_train)

        # Evaluate on validation fold
        y_proba = model.predict_proba(X_val)[:, 1]
        preds = (y_proba >= 0.5).astype(int)

        # AUC (objective)
        fold_auc = roc_auc_score(y_val, y_proba)
        fold_aucs.append(fold_auc)

        # Additional metrics for interpretation
        fold_acc = accuracy_score(y_val, preds)
        fold_accs.append(fold_acc)

        # NF1 Null (C04) is positive class = 1
        rec_null = recall_score(y_val, preds, pos_label=1)    # sensitivity for Null
        rec_wt   = recall_score(y_val, preds, pos_label=0)    # specificity for Null
        prec_null = precision_score(y_val, preds, pos_label=1)

        fold_rec_null.append(rec_null)
        fold_rec_wt.append(rec_wt)
        fold_prec_null.append(prec_null)

        # Store predictions for evaluation (real and shuffled)
        store_pre_evaluation_data(
            X_val, y_val, restdf.iloc[val_index][meta_cols], "val"
        )
        store_pre_evaluation_data(
            X_val_shuf, y_val, restdf.iloc[val_index][meta_cols], "shuffled_val"
        )

        fold_time = (time.time() - fold_start) / 60
        logger.info(
            f"{datetime.now().isoformat(timespec='seconds')} "
            f"[INFO]    Fold {fold}/{n_splits} finished in {fold_time:.2f} min"
        )

    # Average metrics across folds
    mean_auc = float(np.mean(fold_aucs))
    std_auc = float(np.std(fold_aucs))
    mean_acc = float(np.mean(fold_accs))

    mean_rec_null = float(np.mean(fold_rec_null))
    mean_rec_wt   = float(np.mean(fold_rec_wt))
    mean_prec_null = float(np.mean(fold_prec_null))
    mean_bal_acc  = 0.5 * (mean_rec_null + mean_rec_wt)

    # Keep best-performing hyperparameters + their eval data (within this run)
    if mean_auc > best_acc:
        best_acc = mean_auc
        best_hp = rparams
        best_eval_data = {k: v.copy() for k, v in eval_data.items()}

    # Attach metadata to the trial (handy for later analysis)
    trial.set_user_attr("params", rparams)
    trial.set_user_attr("comb_params", comb_params)
    trial.set_user_attr("mean_cv_auc", mean_auc)
    trial.set_user_attr("std_cv_auc", std_auc)
    trial.set_user_attr("mean_cv_acc", mean_acc)
    trial.set_user_attr("mean_cv_recall_null", mean_rec_null)
    trial.set_user_attr("mean_cv_recall_wt", mean_rec_wt)
    trial.set_user_attr("mean_cv_precision_null", mean_prec_null)
    trial.set_user_attr("mean_cv_bal_acc", mean_bal_acc)
    trial.set_user_attr("n_splits", n_splits)

    # Tell Optuna about this trial's result (AUC is objective)
    study.tell(trial, mean_auc)

    iter_time = (time.time() - iter_start) / 60
    logger.info(
        f"{datetime.now().isoformat(timespec='seconds')} "
        f"[INFO] Iteration {global_idx + 1} finished in {iter_time:.2f} min "
        f"(AUC={mean_auc:.4f} ± {std_auc:.4f}, "
        f"ACC={mean_acc:.4f}, "
        f"Null_recall={mean_rec_null:.4f}, "
        f"WT_recall={mean_rec_wt:.4f}, "
        f"Null_precision={mean_prec_null:.4f}, "
        f"best_AUC={best_acc:.4f})"
    )

total_time = (time.time() - overall_start) / 60
logger.info(
    f"{datetime.now().isoformat(timespec='seconds')} "
    f"[INFO] Total search time this session: {total_time:.2f} min"
)

# After running any new trials (or if n_to_run == 0), sync to *global* best over the study
completed_trials = [t for t in study.trials if t.state == TrialState.COMPLETE]
if not completed_trials:
    raise RuntimeError("No completed Optuna trials in the study. Nothing to select as best.")

best_trial = study.best_trial
best_acc = float(best_trial.value)
best_hp = best_trial.params.copy()

logger.info(
    f"{datetime.now().isoformat(timespec='seconds')} "
    f"[INFO] Best average validation AUC (all completed trials) = {best_acc:.4f}"
)
logger.info(f"Best hyperparameters (global over study) = {best_hp}")
# Out:
# [I 2025-12-06 23:39:11,795] Using an existing study with name 'rf_cv' instead of creating a new one.
# 2025-12-06T23:39:11 [train_12_08_16_45_randomforest_train] INFO: 2025-12-06T23:39:11 [INFO] Loaded Optuna study 'rf_cv' with 51 total trials (50 completed). Target total trials = 100. Running 50 new trials in this session.
# 2025-12-06T23:39:11 [train_12_08_16_45_randomforest_train] INFO: 2025-12-06T23:39:11 [INFO] Iteration 51/100: Optuna trial 51, params={'n_estimators': 300, 'max_depth': 40, 'min_samples_leaf': 2, 'max_features': 'sqrt'}
# 2025-12-06T23:39:52 [train_12_08_16_45_randomforest_train] INFO: 2025-12-06T23:39:52 [INFO]    Fold 1/5 finished in 0.67 min
# 2025-12-06T23:40:29 [train_12_08_16_45_randomforest_train] INFO: 2025-12-06T23:40:29 [INFO]    Fold 2/5 finished in 0.62 min
# 2025-12-06T23:41:02 [train_12_08_16_45_randomforest_train] INFO: 2025-12-06T23:41:02 [INFO]    Fold 3/5 finished in 0.55 min
# 2025-12-06T23:41:36 [train_12_08_16_45_randomforest_train] INFO: 2025-12-06T23:41:36 [INFO]    Fold 4/5 finished in 0.56 min
# 2025-12-06T23:42:10 [train_12_08_16_45_randomforest_train] INFO: 2025-12-06T23:42:10 [INFO]    Fold 5/5 finished in 0.57 min
# 2025-12-06T23:42:10 [train_12_08_16_45_randomforest_train] INFO: 2025-12-06T23:42:10 [INFO] Iteration 51 finished in 2.98 min (AUC=0.8445 ± 0.0067, ACC=0.7639, Null_recall=0.7605, WT_recall=0.7673, Null_precision=0.7659, best_AUC=0.8479)
# 2025-12-06T23:42:10 [train_12_08_16_45_randomforest_train] INFO: 2025-12-06T23:42:10 [INFO] Iteration 52/100: Optuna trial 52, params={'n_estimators': 900, 'max_depth': 40, 'min_samples_leaf': 2, 'max_features': 'sqrt'}
# 2025-12-06T23:43:57 [train_12_08_16_45_randomforest_train] INFO: 2025-12-06T23:43:57 [INFO]    Fold 1/5 finished in 1.78 min
# 2025-12-06T23:45:45 [train_12_08_16_45_randomforest_train] INFO: 2025-12-06T23:45:45 [INFO]    Fold 2/5 finished in 1.81 min
# 2025-12-06T23:47:25 [train_12_08_16_45_randomforest_train] INFO: 2025-12-06T23:47:25 [INFO]    Fold 3/5 finished in 1.67 min
# 2025-12-06T23:49:21 [train_12_08_16_45_randomforest_train] INFO: 2025-12-06T23:49:21 [INFO]    Fold 4/5 finished in 1.93 min
# 2025-12-06T23:51:10 [train_12_08_16_45_randomforest_train] INFO: 2025-12-06T23:51:10 [INFO]    Fold 5/5 finished in 1.82 min
# 2025-12-06T23:51:10 [train_12_08_16_45_randomforest_train] INFO: 2025-12-06T23:51:10 [INFO] Iteration 52 finished in 9.01 min (AUC=0.8479 ± 0.0062, ACC=0.7663, Null_recall=0.7619, WT_recall=0.7708, Null_precision=0.7689, best_AUC=0.8479)
# 2025-12-06T23:51:11 [train_12_08_16_45_randomforest_train] INFO: 2025-12-06T23:51:11 [INFO] Iteration 53/100: Optuna trial 53, params={'n_estimators': 900, 'max_depth': 40, 'min_samples_leaf': 2, 'max_features': 'sqrt'}
# 2025-12-06T23:53:00 [train_12_08_16_45_randomforest_train] INFO: 2025-12-06T23:53:00 [INFO]    Fold 1/5 finished in 1.82 min
# 2025-12-06T23:54:48 [train_12_08_16_45_randomforest_train] INFO: 2025-12-06T23:54:48 [INFO]    Fold 2/5 finished in 1.80 min
# 2025-12-06T23:56:46 [train_12_08_16_45_randomforest_train] INFO: 2025-12-06T23:56:46 [INFO]    Fold 3/5 finished in 1.97 min
# 2025-12-06T23:58:56 [train_12_08_16_45_randomforest_train] INFO: 2025-12-06T23:58:56 [INFO]    Fold 4/5 finished in 2.17 min
# 2025-12-07T00:00:49 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:00:49 [INFO]    Fold 5/5 finished in 1.89 min
# 2025-12-07T00:00:49 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:00:49 [INFO] Iteration 53 finished in 9.65 min (AUC=0.8479 ± 0.0062, ACC=0.7663, Null_recall=0.7619, WT_recall=0.7708, Null_precision=0.7689, best_AUC=0.8479)
# 2025-12-07T00:00:49 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:00:49 [INFO] Iteration 54/100: Optuna trial 54, params={'n_estimators': 900, 'max_depth': 40, 'min_samples_leaf': 2, 'max_features': 'sqrt'}
# 2025-12-07T00:02:33 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:02:33 [INFO]    Fold 1/5 finished in 1.72 min
# 2025-12-07T00:04:20 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:04:20 [INFO]    Fold 2/5 finished in 1.79 min
# 2025-12-07T00:06:07 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:06:07 [INFO]    Fold 3/5 finished in 1.78 min
# 2025-12-07T00:07:52 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:07:52 [INFO]    Fold 4/5 finished in 1.76 min
# 2025-12-07T00:09:32 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:09:32 [INFO]    Fold 5/5 finished in 1.66 min
# 2025-12-07T00:09:32 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:09:32 [INFO] Iteration 54 finished in 8.71 min (AUC=0.8479 ± 0.0062, ACC=0.7663, Null_recall=0.7619, WT_recall=0.7708, Null_precision=0.7689, best_AUC=0.8479)
# 2025-12-07T00:09:32 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:09:32 [INFO] Iteration 55/100: Optuna trial 55, params={'n_estimators': 900, 'max_depth': 40, 'min_samples_leaf': 2, 'max_features': 'sqrt'}
# 2025-12-07T00:11:12 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:11:12 [INFO]    Fold 1/5 finished in 1.67 min
# 2025-12-07T00:12:50 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:12:50 [INFO]    Fold 2/5 finished in 1.64 min
# 2025-12-07T00:14:29 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:14:29 [INFO]    Fold 3/5 finished in 1.64 min
# 2025-12-07T00:16:06 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:16:06 [INFO]    Fold 4/5 finished in 1.62 min
# 2025-12-07T00:17:45 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:17:45 [INFO]    Fold 5/5 finished in 1.65 min
# 2025-12-07T00:17:45 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:17:45 [INFO] Iteration 55 finished in 8.22 min (AUC=0.8479 ± 0.0062, ACC=0.7663, Null_recall=0.7619, WT_recall=0.7708, Null_precision=0.7689, best_AUC=0.8479)
# 2025-12-07T00:17:45 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:17:45 [INFO] Iteration 56/100: Optuna trial 56, params={'n_estimators': 900, 'max_depth': 40, 'min_samples_leaf': 2, 'max_features': 'sqrt'}
# 2025-12-07T00:19:22 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:19:22 [INFO]    Fold 1/5 finished in 1.61 min
# 2025-12-07T00:21:01 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:21:01 [INFO]    Fold 2/5 finished in 1.66 min
# 2025-12-07T00:22:39 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:22:39 [INFO]    Fold 3/5 finished in 1.62 min
# 2025-12-07T00:24:15 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:24:15 [INFO]    Fold 4/5 finished in 1.61 min
# 2025-12-07T00:25:51 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:25:51 [INFO]    Fold 5/5 finished in 1.60 min
# 2025-12-07T00:25:52 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:25:52 [INFO] Iteration 56 finished in 8.10 min (AUC=0.8479 ± 0.0062, ACC=0.7663, Null_recall=0.7619, WT_recall=0.7708, Null_precision=0.7689, best_AUC=0.8479)
# 2025-12-07T00:25:52 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:25:52 [INFO] Iteration 57/100: Optuna trial 57, params={'n_estimators': 900, 'max_depth': 40, 'min_samples_leaf': 2, 'max_features': 'sqrt'}
# 2025-12-07T00:27:28 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:27:28 [INFO]    Fold 1/5 finished in 1.60 min
# 2025-12-07T00:29:05 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:29:05 [INFO]    Fold 2/5 finished in 1.62 min
# 2025-12-07T00:30:40 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:30:40 [INFO]    Fold 3/5 finished in 1.59 min
# 2025-12-07T00:32:18 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:32:18 [INFO]    Fold 4/5 finished in 1.63 min
# 2025-12-07T00:33:54 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:33:54 [INFO]    Fold 5/5 finished in 1.60 min
# 2025-12-07T00:33:54 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:33:54 [INFO] Iteration 57 finished in 8.05 min (AUC=0.8479 ± 0.0062, ACC=0.7663, Null_recall=0.7619, WT_recall=0.7708, Null_precision=0.7689, best_AUC=0.8479)
# 2025-12-07T00:33:55 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:33:55 [INFO] Iteration 58/100: Optuna trial 58, params={'n_estimators': 600, 'max_depth': 40, 'min_samples_leaf': 2, 'max_features': 'sqrt'}
# 2025-12-07T00:35:00 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:35:00 [INFO]    Fold 1/5 finished in 1.09 min
# 2025-12-07T00:36:04 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:36:04 [INFO]    Fold 2/5 finished in 1.08 min
# 2025-12-07T00:37:09 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:37:09 [INFO]    Fold 3/5 finished in 1.08 min
# 2025-12-07T00:38:13 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:38:13 [INFO]    Fold 4/5 finished in 1.07 min
# 2025-12-07T00:39:17 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:39:17 [INFO]    Fold 5/5 finished in 1.06 min
# 2025-12-07T00:39:17 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:39:17 [INFO] Iteration 58 finished in 5.38 min (AUC=0.8473 ± 0.0063, ACC=0.7648, Null_recall=0.7614, WT_recall=0.7683, Null_precision=0.7669, best_AUC=0.8479)
# 2025-12-07T00:39:17 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:39:17 [INFO] Iteration 59/100: Optuna trial 59, params={'n_estimators': 900, 'max_depth': 40, 'min_samples_leaf': 2, 'max_features': 'sqrt'}
# 2025-12-07T00:40:53 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:40:53 [INFO]    Fold 1/5 finished in 1.59 min
# 2025-12-07T00:42:29 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:42:29 [INFO]    Fold 2/5 finished in 1.60 min
# 2025-12-07T00:44:05 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:44:05 [INFO]    Fold 3/5 finished in 1.60 min
# 2025-12-07T00:45:42 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:45:42 [INFO]    Fold 4/5 finished in 1.61 min
# 2025-12-07T00:47:20 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:47:20 [INFO]    Fold 5/5 finished in 1.64 min
# 2025-12-07T00:47:20 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:47:20 [INFO] Iteration 59 finished in 8.05 min (AUC=0.8479 ± 0.0062, ACC=0.7663, Null_recall=0.7619, WT_recall=0.7708, Null_precision=0.7689, best_AUC=0.8479)
# 2025-12-07T00:47:20 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:47:20 [INFO] Iteration 60/100: Optuna trial 60, params={'n_estimators': 900, 'max_depth': 40, 'min_samples_leaf': 2, 'max_features': 'sqrt'}
# 2025-12-07T00:48:56 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:48:56 [INFO]    Fold 1/5 finished in 1.60 min
# 2025-12-07T00:50:35 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:50:35 [INFO]    Fold 2/5 finished in 1.65 min
# 2025-12-07T00:52:12 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:52:12 [INFO]    Fold 3/5 finished in 1.63 min
# 2025-12-07T00:53:50 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:53:50 [INFO]    Fold 4/5 finished in 1.62 min
# 2025-12-07T00:55:26 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:55:26 [INFO]    Fold 5/5 finished in 1.60 min
# 2025-12-07T00:55:26 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:55:26 [INFO] Iteration 60 finished in 8.10 min (AUC=0.8479 ± 0.0062, ACC=0.7663, Null_recall=0.7619, WT_recall=0.7708, Null_precision=0.7689, best_AUC=0.8479)
# 2025-12-07T00:55:26 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:55:26 [INFO] Iteration 61/100: Optuna trial 61, params={'n_estimators': 900, 'max_depth': 40, 'min_samples_leaf': 2, 'max_features': 'sqrt'}
# 2025-12-07T00:57:02 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:57:02 [INFO]    Fold 1/5 finished in 1.61 min
# 2025-12-07T00:58:39 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T00:58:39 [INFO]    Fold 2/5 finished in 1.62 min
# 2025-12-07T01:00:16 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:00:16 [INFO]    Fold 3/5 finished in 1.61 min
# 2025-12-07T01:01:52 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:01:52 [INFO]    Fold 4/5 finished in 1.61 min
# 2025-12-07T01:03:28 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:03:28 [INFO]    Fold 5/5 finished in 1.60 min
# 2025-12-07T01:03:28 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:03:28 [INFO] Iteration 61 finished in 8.04 min (AUC=0.8479 ± 0.0062, ACC=0.7663, Null_recall=0.7619, WT_recall=0.7708, Null_precision=0.7689, best_AUC=0.8479)
# 2025-12-07T01:03:29 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:03:29 [INFO] Iteration 62/100: Optuna trial 62, params={'n_estimators': 900, 'max_depth': 40, 'min_samples_leaf': 2, 'max_features': 'sqrt'}
# 2025-12-07T01:05:05 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:05:05 [INFO]    Fold 1/5 finished in 1.60 min
# 2025-12-07T01:06:41 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:06:41 [INFO]    Fold 2/5 finished in 1.60 min
# 2025-12-07T01:08:17 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:08:17 [INFO]    Fold 3/5 finished in 1.60 min
# 2025-12-07T01:09:52 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:09:52 [INFO]    Fold 4/5 finished in 1.60 min
# 2025-12-07T01:11:31 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:11:31 [INFO]    Fold 5/5 finished in 1.64 min
# 2025-12-07T01:11:31 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:11:31 [INFO] Iteration 62 finished in 8.04 min (AUC=0.8479 ± 0.0062, ACC=0.7663, Null_recall=0.7619, WT_recall=0.7708, Null_precision=0.7689, best_AUC=0.8479)
# 2025-12-07T01:11:31 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:11:31 [INFO] Iteration 63/100: Optuna trial 63, params={'n_estimators': 900, 'max_depth': 40, 'min_samples_leaf': 2, 'max_features': 'sqrt'}
# 2025-12-07T01:13:06 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:13:06 [INFO]    Fold 1/5 finished in 1.58 min
# 2025-12-07T01:14:43 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:14:43 [INFO]    Fold 2/5 finished in 1.62 min
# 2025-12-07T01:16:24 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:16:24 [INFO]    Fold 3/5 finished in 1.68 min
# 2025-12-07T01:18:00 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:18:00 [INFO]    Fold 4/5 finished in 1.61 min
# 2025-12-07T01:19:38 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:19:38 [INFO]    Fold 5/5 finished in 1.63 min
# 2025-12-07T01:19:38 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:19:38 [INFO] Iteration 63 finished in 8.12 min (AUC=0.8479 ± 0.0062, ACC=0.7663, Null_recall=0.7619, WT_recall=0.7708, Null_precision=0.7689, best_AUC=0.8479)
# 2025-12-07T01:19:38 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:19:38 [INFO] Iteration 64/100: Optuna trial 64, params={'n_estimators': 900, 'max_depth': 40, 'min_samples_leaf': 2, 'max_features': 'sqrt'}
# 2025-12-07T01:21:13 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:21:13 [INFO]    Fold 1/5 finished in 1.58 min
# 2025-12-07T01:22:51 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:22:51 [INFO]    Fold 2/5 finished in 1.64 min
# 2025-12-07T01:24:28 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:24:28 [INFO]    Fold 3/5 finished in 1.60 min
# 2025-12-07T01:26:04 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:26:04 [INFO]    Fold 4/5 finished in 1.60 min
# 2025-12-07T01:27:39 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:27:39 [INFO]    Fold 5/5 finished in 1.59 min
# 2025-12-07T01:27:39 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:27:39 [INFO] Iteration 64 finished in 8.02 min (AUC=0.8479 ± 0.0062, ACC=0.7663, Null_recall=0.7619, WT_recall=0.7708, Null_precision=0.7689, best_AUC=0.8479)
# 2025-12-07T01:27:39 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:27:39 [INFO] Iteration 65/100: Optuna trial 65, params={'n_estimators': 900, 'max_depth': 60, 'min_samples_leaf': 2, 'max_features': 'sqrt'}
# 2025-12-07T01:29:14 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:29:14 [INFO]    Fold 1/5 finished in 1.59 min
# 2025-12-07T01:30:51 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:30:51 [INFO]    Fold 2/5 finished in 1.60 min
# 2025-12-07T01:32:26 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:32:26 [INFO]    Fold 3/5 finished in 1.59 min
# 2025-12-07T01:34:02 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:34:02 [INFO]    Fold 4/5 finished in 1.61 min
# 2025-12-07T01:35:38 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:35:38 [INFO]    Fold 5/5 finished in 1.59 min
# 2025-12-07T01:35:38 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:35:38 [INFO] Iteration 65 finished in 7.98 min (AUC=0.8479 ± 0.0062, ACC=0.7657, Null_recall=0.7608, WT_recall=0.7707, Null_precision=0.7685, best_AUC=0.8479)
# 2025-12-07T01:35:38 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:35:38 [INFO] Iteration 66/100: Optuna trial 66, params={'n_estimators': 900, 'max_depth': 20, 'min_samples_leaf': 2, 'max_features': 'sqrt'}
# 2025-12-07T01:37:12 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:37:12 [INFO]    Fold 1/5 finished in 1.56 min
# 2025-12-07T01:38:44 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:38:44 [INFO]    Fold 2/5 finished in 1.54 min
# 2025-12-07T01:40:16 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:40:16 [INFO]    Fold 3/5 finished in 1.54 min
# 2025-12-07T01:41:48 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:41:48 [INFO]    Fold 4/5 finished in 1.52 min
# 2025-12-07T01:43:20 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:43:20 [INFO]    Fold 5/5 finished in 1.53 min
# 2025-12-07T01:43:20 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:43:20 [INFO] Iteration 66 finished in 7.69 min (AUC=0.8464 ± 0.0058, ACC=0.7635, Null_recall=0.7585, WT_recall=0.7685, Null_precision=0.7664, best_AUC=0.8479)
# 2025-12-07T01:43:20 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:43:20 [INFO] Iteration 67/100: Optuna trial 67, params={'n_estimators': 900, 'max_depth': 40, 'min_samples_leaf': 2, 'max_features': 'sqrt'}
# 2025-12-07T01:44:59 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:44:59 [INFO]    Fold 1/5 finished in 1.65 min
# 2025-12-07T01:46:37 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:46:37 [INFO]    Fold 2/5 finished in 1.63 min
# 2025-12-07T01:48:12 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:48:12 [INFO]    Fold 3/5 finished in 1.59 min
# 2025-12-07T01:49:49 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:49:49 [INFO]    Fold 4/5 finished in 1.62 min
# 2025-12-07T01:51:25 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:51:25 [INFO]    Fold 5/5 finished in 1.59 min
# 2025-12-07T01:51:25 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:51:25 [INFO] Iteration 67 finished in 8.09 min (AUC=0.8479 ± 0.0062, ACC=0.7663, Null_recall=0.7619, WT_recall=0.7708, Null_precision=0.7689, best_AUC=0.8479)
# 2025-12-07T01:51:25 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:51:25 [INFO] Iteration 68/100: Optuna trial 68, params={'n_estimators': 900, 'max_depth': 40, 'min_samples_leaf': 4, 'max_features': 'sqrt'}
# 2025-12-07T01:52:52 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:52:52 [INFO]    Fold 1/5 finished in 1.45 min
# 2025-12-07T01:54:19 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:54:19 [INFO]    Fold 2/5 finished in 1.44 min
# 2025-12-07T01:55:46 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:55:46 [INFO]    Fold 3/5 finished in 1.45 min
# 2025-12-07T01:57:12 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:57:12 [INFO]    Fold 4/5 finished in 1.44 min
# 2025-12-07T01:58:41 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:58:41 [INFO]    Fold 5/5 finished in 1.49 min
# 2025-12-07T01:58:41 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:58:41 [INFO] Iteration 68 finished in 7.27 min (AUC=0.8458 ± 0.0064, ACC=0.7653, Null_recall=0.7596, WT_recall=0.7709, Null_precision=0.7685, best_AUC=0.8479)
# 2025-12-07T01:58:41 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T01:58:41 [INFO] Iteration 69/100: Optuna trial 69, params={'n_estimators': 900, 'max_depth': 40, 'min_samples_leaf': 2, 'max_features': 'sqrt'}
# 2025-12-07T02:00:16 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:00:16 [INFO]    Fold 1/5 finished in 1.57 min
# 2025-12-07T02:01:53 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:01:53 [INFO]    Fold 2/5 finished in 1.61 min
# 2025-12-07T02:03:29 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:03:29 [INFO]    Fold 3/5 finished in 1.61 min
# 2025-12-07T02:05:06 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:05:06 [INFO]    Fold 4/5 finished in 1.61 min
# 2025-12-07T02:06:40 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:06:40 [INFO]    Fold 5/5 finished in 1.56 min
# 2025-12-07T02:06:40 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:06:40 [INFO] Iteration 69 finished in 7.97 min (AUC=0.8479 ± 0.0062, ACC=0.7663, Null_recall=0.7619, WT_recall=0.7708, Null_precision=0.7689, best_AUC=0.8479)
# 2025-12-07T02:06:40 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:06:40 [INFO] Iteration 70/100: Optuna trial 70, params={'n_estimators': 900, 'max_depth': 40, 'min_samples_leaf': 1, 'max_features': 'sqrt'}
# 2025-12-07T02:08:21 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:08:21 [INFO]    Fold 1/5 finished in 1.69 min
# 2025-12-07T02:10:02 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:10:02 [INFO]    Fold 2/5 finished in 1.69 min
# 2025-12-07T02:11:44 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:11:44 [INFO]    Fold 3/5 finished in 1.70 min
# 2025-12-07T02:13:27 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:13:27 [INFO]    Fold 4/5 finished in 1.71 min
# 2025-12-07T02:15:14 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:15:14 [INFO]    Fold 5/5 finished in 1.79 min
# 2025-12-07T02:15:14 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:15:14 [INFO] Iteration 70 finished in 8.58 min (AUC=0.8478 ± 0.0063, ACC=0.7665, Null_recall=0.7626, WT_recall=0.7704, Null_precision=0.7688, best_AUC=0.8479)
# 2025-12-07T02:15:15 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:15:15 [INFO] Iteration 71/100: Optuna trial 71, params={'n_estimators': 900, 'max_depth': 40, 'min_samples_leaf': 2, 'max_features': 'log2'}
# 2025-12-07T02:15:47 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:15:47 [INFO]    Fold 1/5 finished in 0.55 min
# 2025-12-07T02:16:21 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:16:21 [INFO]    Fold 2/5 finished in 0.57 min
# 2025-12-07T02:16:54 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:16:54 [INFO]    Fold 3/5 finished in 0.55 min
# 2025-12-07T02:17:29 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:17:29 [INFO]    Fold 4/5 finished in 0.57 min
# 2025-12-07T02:18:03 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:18:03 [INFO]    Fold 5/5 finished in 0.57 min
# 2025-12-07T02:18:03 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:18:03 [INFO] Iteration 71 finished in 2.80 min (AUC=0.8332 ± 0.0073, ACC=0.7513, Null_recall=0.7418, WT_recall=0.7608, Null_precision=0.7564, best_AUC=0.8479)
# 2025-12-07T02:18:03 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:18:03 [INFO] Iteration 72/100: Optuna trial 72, params={'n_estimators': 900, 'max_depth': 40, 'min_samples_leaf': 2, 'max_features': 'sqrt'}
# 2025-12-07T02:19:38 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:19:38 [INFO]    Fold 1/5 finished in 1.59 min
# 2025-12-07T02:21:15 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:21:15 [INFO]    Fold 2/5 finished in 1.61 min
# 2025-12-07T02:22:51 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:22:51 [INFO]    Fold 3/5 finished in 1.60 min
# 2025-12-07T02:24:25 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:24:25 [INFO]    Fold 4/5 finished in 1.56 min
# 2025-12-07T02:26:00 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:26:00 [INFO]    Fold 5/5 finished in 1.59 min
# 2025-12-07T02:26:00 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:26:00 [INFO] Iteration 72 finished in 7.95 min (AUC=0.8479 ± 0.0062, ACC=0.7663, Null_recall=0.7619, WT_recall=0.7708, Null_precision=0.7689, best_AUC=0.8479)
# 2025-12-07T02:26:00 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:26:00 [INFO] Iteration 73/100: Optuna trial 73, params={'n_estimators': 900, 'max_depth': 40, 'min_samples_leaf': 2, 'max_features': 'sqrt'}
# 2025-12-07T02:27:34 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:27:34 [INFO]    Fold 1/5 finished in 1.57 min
# 2025-12-07T02:29:10 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:29:10 [INFO]    Fold 2/5 finished in 1.60 min
# 2025-12-07T02:30:44 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:30:44 [INFO]    Fold 3/5 finished in 1.56 min
# 2025-12-07T02:32:19 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:32:19 [INFO]    Fold 4/5 finished in 1.59 min
# 2025-12-07T02:33:54 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:33:54 [INFO]    Fold 5/5 finished in 1.58 min
# 2025-12-07T02:33:54 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:33:54 [INFO] Iteration 73 finished in 7.89 min (AUC=0.8479 ± 0.0062, ACC=0.7663, Null_recall=0.7619, WT_recall=0.7708, Null_precision=0.7689, best_AUC=0.8479)
# 2025-12-07T02:33:54 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:33:54 [INFO] Iteration 74/100: Optuna trial 74, params={'n_estimators': 900, 'max_depth': 40, 'min_samples_leaf': 2, 'max_features': 'sqrt'}
# 2025-12-07T02:35:26 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:35:26 [INFO]    Fold 1/5 finished in 1.54 min
# 2025-12-07T02:37:02 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:37:02 [INFO]    Fold 2/5 finished in 1.60 min
# 2025-12-07T02:38:36 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:38:36 [INFO]    Fold 3/5 finished in 1.56 min
# 2025-12-07T02:40:13 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:40:13 [INFO]    Fold 4/5 finished in 1.61 min
# 2025-12-07T02:41:48 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:41:48 [INFO]    Fold 5/5 finished in 1.59 min
# 2025-12-07T02:41:48 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:41:48 [INFO] Iteration 74 finished in 7.91 min (AUC=0.8479 ± 0.0062, ACC=0.7663, Null_recall=0.7619, WT_recall=0.7708, Null_precision=0.7689, best_AUC=0.8479)
# 2025-12-07T02:41:48 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:41:48 [INFO] Iteration 75/100: Optuna trial 75, params={'n_estimators': 900, 'max_depth': 20, 'min_samples_leaf': 2, 'max_features': 'sqrt'}
# 2025-12-07T02:43:18 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:43:18 [INFO]    Fold 1/5 finished in 1.49 min
# 2025-12-07T02:44:52 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:44:52 [INFO]    Fold 2/5 finished in 1.57 min
# 2025-12-07T02:46:24 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:46:24 [INFO]    Fold 3/5 finished in 1.53 min
# 2025-12-07T02:47:57 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:47:57 [INFO]    Fold 4/5 finished in 1.56 min
# 2025-12-07T02:49:29 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:49:29 [INFO]    Fold 5/5 finished in 1.53 min
# 2025-12-07T02:49:29 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:49:29 [INFO] Iteration 75 finished in 7.68 min (AUC=0.8464 ± 0.0058, ACC=0.7635, Null_recall=0.7585, WT_recall=0.7685, Null_precision=0.7664, best_AUC=0.8479)
# 2025-12-07T02:49:29 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:49:29 [INFO] Iteration 76/100: Optuna trial 76, params={'n_estimators': 900, 'max_depth': 40, 'min_samples_leaf': 2, 'max_features': 'sqrt'}
# 2025-12-07T02:51:04 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:51:04 [INFO]    Fold 1/5 finished in 1.58 min
# 2025-12-07T02:52:39 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:52:39 [INFO]    Fold 2/5 finished in 1.57 min
# 2025-12-07T02:54:12 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:54:12 [INFO]    Fold 3/5 finished in 1.56 min
# 2025-12-07T02:55:48 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:55:48 [INFO]    Fold 4/5 finished in 1.59 min
# 2025-12-07T02:57:23 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:57:23 [INFO]    Fold 5/5 finished in 1.59 min
# 2025-12-07T02:57:23 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:57:23 [INFO] Iteration 76 finished in 7.90 min (AUC=0.8479 ± 0.0062, ACC=0.7663, Null_recall=0.7619, WT_recall=0.7708, Null_precision=0.7689, best_AUC=0.8479)
# 2025-12-07T02:57:23 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:57:23 [INFO] Iteration 77/100: Optuna trial 77, params={'n_estimators': 300, 'max_depth': 60, 'min_samples_leaf': 2, 'max_features': 'sqrt'}
# 2025-12-07T02:57:57 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:57:57 [INFO]    Fold 1/5 finished in 0.56 min
# 2025-12-07T02:58:30 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:58:30 [INFO]    Fold 2/5 finished in 0.55 min
# 2025-12-07T02:59:03 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:59:03 [INFO]    Fold 3/5 finished in 0.54 min
# 2025-12-07T02:59:37 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T02:59:37 [INFO]    Fold 4/5 finished in 0.58 min
# 2025-12-07T03:00:10 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:00:10 [INFO]    Fold 5/5 finished in 0.55 min
# 2025-12-07T03:00:10 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:00:10 [INFO] Iteration 77 finished in 2.79 min (AUC=0.8445 ± 0.0067, ACC=0.7644, Null_recall=0.7616, WT_recall=0.7672, Null_precision=0.7661, best_AUC=0.8479)
# 2025-12-07T03:00:11 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:00:11 [INFO] Iteration 78/100: Optuna trial 78, params={'n_estimators': 900, 'max_depth': 40, 'min_samples_leaf': 2, 'max_features': 'sqrt'}
# 2025-12-07T03:01:47 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:01:47 [INFO]    Fold 1/5 finished in 1.60 min
# 2025-12-07T03:03:24 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:03:24 [INFO]    Fold 2/5 finished in 1.62 min
# 2025-12-07T03:04:58 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:04:58 [INFO]    Fold 3/5 finished in 1.57 min
# 2025-12-07T03:06:32 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:06:32 [INFO]    Fold 4/5 finished in 1.56 min
# 2025-12-07T03:08:07 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:08:07 [INFO]    Fold 5/5 finished in 1.59 min
# 2025-12-07T03:08:07 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:08:07 [INFO] Iteration 78 finished in 7.94 min (AUC=0.8479 ± 0.0062, ACC=0.7663, Null_recall=0.7619, WT_recall=0.7708, Null_precision=0.7689, best_AUC=0.8479)
# 2025-12-07T03:08:07 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:08:07 [INFO] Iteration 79/100: Optuna trial 79, params={'n_estimators': 600, 'max_depth': 40, 'min_samples_leaf': 2, 'max_features': 'sqrt'}
# 2025-12-07T03:09:09 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:09:09 [INFO]    Fold 1/5 finished in 1.04 min
# 2025-12-07T03:10:13 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:10:13 [INFO]    Fold 2/5 finished in 1.06 min
# 2025-12-07T03:11:16 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:11:16 [INFO]    Fold 3/5 finished in 1.05 min
# 2025-12-07T03:12:20 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:12:20 [INFO]    Fold 4/5 finished in 1.07 min
# 2025-12-07T03:13:24 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:13:24 [INFO]    Fold 5/5 finished in 1.05 min
# 2025-12-07T03:13:24 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:13:24 [INFO] Iteration 79 finished in 5.28 min (AUC=0.8473 ± 0.0063, ACC=0.7648, Null_recall=0.7614, WT_recall=0.7683, Null_precision=0.7669, best_AUC=0.8479)
# 2025-12-07T03:13:24 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:13:24 [INFO] Iteration 80/100: Optuna trial 80, params={'n_estimators': 900, 'max_depth': 40, 'min_samples_leaf': 2, 'max_features': 'sqrt'}
# 2025-12-07T03:14:59 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:14:59 [INFO]    Fold 1/5 finished in 1.59 min
# 2025-12-07T03:16:32 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:16:32 [INFO]    Fold 2/5 finished in 1.56 min
# 2025-12-07T03:18:10 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:18:10 [INFO]    Fold 3/5 finished in 1.63 min
# 2025-12-07T03:19:46 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:19:46 [INFO]    Fold 4/5 finished in 1.59 min
# 2025-12-07T03:21:20 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:21:20 [INFO]    Fold 5/5 finished in 1.57 min
# 2025-12-07T03:21:20 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:21:20 [INFO] Iteration 80 finished in 7.94 min (AUC=0.8479 ± 0.0062, ACC=0.7663, Null_recall=0.7619, WT_recall=0.7708, Null_precision=0.7689, best_AUC=0.8479)
# 2025-12-07T03:21:20 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:21:20 [INFO] Iteration 81/100: Optuna trial 81, params={'n_estimators': 900, 'max_depth': 40, 'min_samples_leaf': 4, 'max_features': 'sqrt'}
# 2025-12-07T03:22:44 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:22:44 [INFO]    Fold 1/5 finished in 1.40 min
# 2025-12-07T03:24:11 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:24:11 [INFO]    Fold 2/5 finished in 1.45 min
# 2025-12-07T03:25:36 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:25:36 [INFO]    Fold 3/5 finished in 1.42 min
# 2025-12-07T03:27:04 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:27:04 [INFO]    Fold 4/5 finished in 1.46 min
# 2025-12-07T03:28:30 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:28:30 [INFO]    Fold 5/5 finished in 1.44 min
# 2025-12-07T03:28:30 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:28:30 [INFO] Iteration 81 finished in 7.17 min (AUC=0.8458 ± 0.0064, ACC=0.7653, Null_recall=0.7596, WT_recall=0.7709, Null_precision=0.7685, best_AUC=0.8479)
# 2025-12-07T03:28:30 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:28:30 [INFO] Iteration 82/100: Optuna trial 82, params={'n_estimators': 900, 'max_depth': 40, 'min_samples_leaf': 2, 'max_features': 'sqrt'}
# 2025-12-07T03:30:03 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:30:03 [INFO]    Fold 1/5 finished in 1.54 min
# 2025-12-07T03:31:38 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:31:38 [INFO]    Fold 2/5 finished in 1.58 min
# 2025-12-07T03:33:11 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:33:11 [INFO]    Fold 3/5 finished in 1.55 min
# 2025-12-07T03:34:46 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:34:46 [INFO]    Fold 4/5 finished in 1.58 min
# 2025-12-07T03:36:22 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:36:22 [INFO]    Fold 5/5 finished in 1.60 min
# 2025-12-07T03:36:22 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:36:22 [INFO] Iteration 82 finished in 7.86 min (AUC=0.8479 ± 0.0062, ACC=0.7663, Null_recall=0.7619, WT_recall=0.7708, Null_precision=0.7689, best_AUC=0.8479)
# 2025-12-07T03:36:22 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:36:22 [INFO] Iteration 83/100: Optuna trial 83, params={'n_estimators': 900, 'max_depth': 40, 'min_samples_leaf': 2, 'max_features': 'sqrt'}
# 2025-12-07T03:37:55 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:37:55 [INFO]    Fold 1/5 finished in 1.55 min
# 2025-12-07T03:39:30 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:39:30 [INFO]    Fold 2/5 finished in 1.59 min
# 2025-12-07T03:41:04 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:41:04 [INFO]    Fold 3/5 finished in 1.57 min
# 2025-12-07T03:42:39 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:42:39 [INFO]    Fold 4/5 finished in 1.59 min
# 2025-12-07T03:44:13 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:44:13 [INFO]    Fold 5/5 finished in 1.57 min
# 2025-12-07T03:44:13 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:44:13 [INFO] Iteration 83 finished in 7.86 min (AUC=0.8479 ± 0.0062, ACC=0.7663, Null_recall=0.7619, WT_recall=0.7708, Null_precision=0.7689, best_AUC=0.8479)
# 2025-12-07T03:44:13 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:44:13 [INFO] Iteration 84/100: Optuna trial 84, params={'n_estimators': 900, 'max_depth': 40, 'min_samples_leaf': 2, 'max_features': 'sqrt'}
# 2025-12-07T03:45:47 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:45:47 [INFO]    Fold 1/5 finished in 1.56 min
# 2025-12-07T03:47:22 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:47:22 [INFO]    Fold 2/5 finished in 1.58 min
# 2025-12-07T03:48:57 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:48:57 [INFO]    Fold 3/5 finished in 1.58 min
# 2025-12-07T03:50:32 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:50:32 [INFO]    Fold 4/5 finished in 1.58 min
# 2025-12-07T03:52:12 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:52:12 [INFO]    Fold 5/5 finished in 1.67 min
# 2025-12-07T03:52:12 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:52:12 [INFO] Iteration 84 finished in 7.97 min (AUC=0.8479 ± 0.0062, ACC=0.7663, Null_recall=0.7619, WT_recall=0.7708, Null_precision=0.7689, best_AUC=0.8479)
# 2025-12-07T03:52:12 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:52:12 [INFO] Iteration 85/100: Optuna trial 85, params={'n_estimators': 900, 'max_depth': 40, 'min_samples_leaf': 2, 'max_features': 'sqrt'}
# 2025-12-07T03:53:48 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:53:48 [INFO]    Fold 1/5 finished in 1.59 min
# 2025-12-07T03:55:22 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:55:22 [INFO]    Fold 2/5 finished in 1.58 min
# 2025-12-07T03:56:58 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:56:58 [INFO]    Fold 3/5 finished in 1.59 min
# 2025-12-07T03:58:32 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T03:58:32 [INFO]    Fold 4/5 finished in 1.57 min
# 2025-12-07T04:00:09 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:00:09 [INFO]    Fold 5/5 finished in 1.61 min
# 2025-12-07T04:00:09 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:00:09 [INFO] Iteration 85 finished in 7.95 min (AUC=0.8479 ± 0.0062, ACC=0.7663, Null_recall=0.7619, WT_recall=0.7708, Null_precision=0.7689, best_AUC=0.8479)
# 2025-12-07T04:00:09 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:00:09 [INFO] Iteration 86/100: Optuna trial 86, params={'n_estimators': 900, 'max_depth': 40, 'min_samples_leaf': 2, 'max_features': 'sqrt'}
# 2025-12-07T04:01:45 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:01:45 [INFO]    Fold 1/5 finished in 1.60 min
# 2025-12-07T04:03:21 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:03:21 [INFO]    Fold 2/5 finished in 1.61 min
# 2025-12-07T04:04:56 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:04:56 [INFO]    Fold 3/5 finished in 1.57 min
# 2025-12-07T04:06:32 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:06:32 [INFO]    Fold 4/5 finished in 1.60 min
# 2025-12-07T04:08:06 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:08:06 [INFO]    Fold 5/5 finished in 1.57 min
# 2025-12-07T04:08:06 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:08:06 [INFO] Iteration 86 finished in 7.95 min (AUC=0.8479 ± 0.0062, ACC=0.7663, Null_recall=0.7619, WT_recall=0.7708, Null_precision=0.7689, best_AUC=0.8479)
# 2025-12-07T04:08:06 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:08:06 [INFO] Iteration 87/100: Optuna trial 87, params={'n_estimators': 900, 'max_depth': 40, 'min_samples_leaf': 1, 'max_features': 'log2'}
# 2025-12-07T04:08:41 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:08:41 [INFO]    Fold 1/5 finished in 0.58 min
# 2025-12-07T04:09:15 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:09:15 [INFO]    Fold 2/5 finished in 0.57 min
# 2025-12-07T04:09:49 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:09:49 [INFO]    Fold 3/5 finished in 0.56 min
# 2025-12-07T04:10:24 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:10:24 [INFO]    Fold 4/5 finished in 0.60 min
# 2025-12-07T04:11:00 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:11:00 [INFO]    Fold 5/5 finished in 0.60 min
# 2025-12-07T04:11:00 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:11:00 [INFO] Iteration 87 finished in 2.91 min (AUC=0.8342 ± 0.0062, ACC=0.7528, Null_recall=0.7470, WT_recall=0.7587, Null_precision=0.7561, best_AUC=0.8479)
# 2025-12-07T04:11:00 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:11:00 [INFO] Iteration 88/100: Optuna trial 88, params={'n_estimators': 900, 'max_depth': 20, 'min_samples_leaf': 2, 'max_features': 'sqrt'}
# 2025-12-07T04:12:35 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:12:35 [INFO]    Fold 1/5 finished in 1.57 min
# 2025-12-07T04:14:06 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:14:06 [INFO]    Fold 2/5 finished in 1.53 min
# 2025-12-07T04:15:41 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:15:41 [INFO]    Fold 3/5 finished in 1.57 min
# 2025-12-07T04:17:13 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:17:13 [INFO]    Fold 4/5 finished in 1.54 min
# 2025-12-07T04:18:44 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:18:44 [INFO]    Fold 5/5 finished in 1.51 min
# 2025-12-07T04:18:44 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:18:44 [INFO] Iteration 88 finished in 7.72 min (AUC=0.8464 ± 0.0058, ACC=0.7635, Null_recall=0.7585, WT_recall=0.7685, Null_precision=0.7664, best_AUC=0.8479)
# 2025-12-07T04:18:44 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:18:44 [INFO] Iteration 89/100: Optuna trial 89, params={'n_estimators': 300, 'max_depth': 40, 'min_samples_leaf': 2, 'max_features': 'sqrt'}
# 2025-12-07T04:19:18 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:19:18 [INFO]    Fold 1/5 finished in 0.57 min
# 2025-12-07T04:19:52 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:19:52 [INFO]    Fold 2/5 finished in 0.56 min
# 2025-12-07T04:20:26 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:20:26 [INFO]    Fold 3/5 finished in 0.57 min
# 2025-12-07T04:20:59 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:20:59 [INFO]    Fold 4/5 finished in 0.54 min
# 2025-12-07T04:21:33 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:21:33 [INFO]    Fold 5/5 finished in 0.57 min
# 2025-12-07T04:21:33 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:21:33 [INFO] Iteration 89 finished in 2.81 min (AUC=0.8445 ± 0.0067, ACC=0.7639, Null_recall=0.7605, WT_recall=0.7673, Null_precision=0.7659, best_AUC=0.8479)
# 2025-12-07T04:21:33 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:21:33 [INFO] Iteration 90/100: Optuna trial 90, params={'n_estimators': 900, 'max_depth': 60, 'min_samples_leaf': 2, 'max_features': 'sqrt'}
# 2025-12-07T04:23:08 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:23:08 [INFO]    Fold 1/5 finished in 1.59 min
# 2025-12-07T04:24:44 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:24:44 [INFO]    Fold 2/5 finished in 1.60 min
# 2025-12-07T04:26:17 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:26:17 [INFO]    Fold 3/5 finished in 1.55 min
# 2025-12-07T04:27:52 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:27:52 [INFO]    Fold 4/5 finished in 1.58 min
# 2025-12-07T04:29:25 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:29:25 [INFO]    Fold 5/5 finished in 1.55 min
# 2025-12-07T04:29:25 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:29:25 [INFO] Iteration 90 finished in 7.87 min (AUC=0.8479 ± 0.0062, ACC=0.7657, Null_recall=0.7608, WT_recall=0.7707, Null_precision=0.7685, best_AUC=0.8479)
# 2025-12-07T04:29:25 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:29:25 [INFO] Iteration 91/100: Optuna trial 91, params={'n_estimators': 900, 'max_depth': 40, 'min_samples_leaf': 2, 'max_features': 'sqrt'}
# 2025-12-07T04:30:57 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:30:57 [INFO]    Fold 1/5 finished in 1.54 min
# 2025-12-07T04:32:32 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:32:32 [INFO]    Fold 2/5 finished in 1.57 min
# 2025-12-07T04:34:04 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:34:04 [INFO]    Fold 3/5 finished in 1.54 min
# 2025-12-07T04:35:38 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:35:38 [INFO]    Fold 4/5 finished in 1.56 min
# 2025-12-07T04:37:12 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:37:12 [INFO]    Fold 5/5 finished in 1.56 min
# 2025-12-07T04:37:12 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:37:12 [INFO] Iteration 91 finished in 7.78 min (AUC=0.8479 ± 0.0062, ACC=0.7663, Null_recall=0.7619, WT_recall=0.7708, Null_precision=0.7689, best_AUC=0.8479)
# 2025-12-07T04:37:12 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:37:12 [INFO] Iteration 92/100: Optuna trial 92, params={'n_estimators': 900, 'max_depth': 40, 'min_samples_leaf': 2, 'max_features': 'sqrt'}
# 2025-12-07T04:38:45 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:38:45 [INFO]    Fold 1/5 finished in 1.55 min
# 2025-12-07T04:40:18 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:40:18 [INFO]    Fold 2/5 finished in 1.56 min
# 2025-12-07T04:41:51 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:41:51 [INFO]    Fold 3/5 finished in 1.54 min
# 2025-12-07T04:43:25 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:43:25 [INFO]    Fold 4/5 finished in 1.57 min
# 2025-12-07T04:44:59 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:44:59 [INFO]    Fold 5/5 finished in 1.57 min
# 2025-12-07T04:44:59 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:44:59 [INFO] Iteration 92 finished in 7.79 min (AUC=0.8479 ± 0.0062, ACC=0.7663, Null_recall=0.7619, WT_recall=0.7708, Null_precision=0.7689, best_AUC=0.8479)
# 2025-12-07T04:44:59 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:44:59 [INFO] Iteration 93/100: Optuna trial 93, params={'n_estimators': 900, 'max_depth': 40, 'min_samples_leaf': 2, 'max_features': 'sqrt'}
# 2025-12-07T04:46:32 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:46:32 [INFO]    Fold 1/5 finished in 1.55 min
# 2025-12-07T04:48:06 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:48:06 [INFO]    Fold 2/5 finished in 1.56 min
# 2025-12-07T04:49:39 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:49:39 [INFO]    Fold 3/5 finished in 1.54 min
# 2025-12-07T04:51:14 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:51:14 [INFO]    Fold 4/5 finished in 1.59 min
# 2025-12-07T04:52:51 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:52:51 [INFO]    Fold 5/5 finished in 1.61 min
# 2025-12-07T04:52:51 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:52:51 [INFO] Iteration 93 finished in 7.86 min (AUC=0.8479 ± 0.0062, ACC=0.7663, Null_recall=0.7619, WT_recall=0.7708, Null_precision=0.7689, best_AUC=0.8479)
# 2025-12-07T04:52:51 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:52:51 [INFO] Iteration 94/100: Optuna trial 94, params={'n_estimators': 900, 'max_depth': 40, 'min_samples_leaf': 2, 'max_features': 'sqrt'}
# 2025-12-07T04:54:27 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:54:27 [INFO]    Fold 1/5 finished in 1.60 min
# 2025-12-07T04:56:00 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:56:00 [INFO]    Fold 2/5 finished in 1.55 min
# 2025-12-07T04:57:36 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:57:36 [INFO]    Fold 3/5 finished in 1.60 min
# 2025-12-07T04:59:12 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T04:59:12 [INFO]    Fold 4/5 finished in 1.60 min
# 2025-12-07T05:00:45 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T05:00:45 [INFO]    Fold 5/5 finished in 1.56 min
# 2025-12-07T05:00:45 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T05:00:45 [INFO] Iteration 94 finished in 7.91 min (AUC=0.8479 ± 0.0062, ACC=0.7663, Null_recall=0.7619, WT_recall=0.7708, Null_precision=0.7689, best_AUC=0.8479)
# 2025-12-07T05:00:45 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T05:00:45 [INFO] Iteration 95/100: Optuna trial 95, params={'n_estimators': 900, 'max_depth': 40, 'min_samples_leaf': 2, 'max_features': 'sqrt'}
# 2025-12-07T05:02:20 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T05:02:20 [INFO]    Fold 1/5 finished in 1.57 min
# 2025-12-07T05:03:53 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T05:03:53 [INFO]    Fold 2/5 finished in 1.56 min
# 2025-12-07T05:05:26 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T05:05:26 [INFO]    Fold 3/5 finished in 1.55 min
# 2025-12-07T05:06:58 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T05:06:58 [INFO]    Fold 4/5 finished in 1.53 min
# 2025-12-07T05:08:36 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T05:08:36 [INFO]    Fold 5/5 finished in 1.63 min
# 2025-12-07T05:08:36 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T05:08:36 [INFO] Iteration 95 finished in 7.84 min (AUC=0.8479 ± 0.0062, ACC=0.7663, Null_recall=0.7619, WT_recall=0.7708, Null_precision=0.7689, best_AUC=0.8479)
# 2025-12-07T05:08:36 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T05:08:36 [INFO] Iteration 96/100: Optuna trial 96, params={'n_estimators': 600, 'max_depth': 40, 'min_samples_leaf': 2, 'max_features': 'sqrt'}
# 2025-12-07T05:09:42 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T05:09:42 [INFO]    Fold 1/5 finished in 1.10 min
# 2025-12-07T05:10:48 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T05:10:48 [INFO]    Fold 2/5 finished in 1.11 min
# 2025-12-07T05:11:56 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T05:11:56 [INFO]    Fold 3/5 finished in 1.12 min
# 2025-12-07T05:13:01 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T05:13:01 [INFO]    Fold 4/5 finished in 1.09 min
# 2025-12-07T05:14:05 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T05:14:05 [INFO]    Fold 5/5 finished in 1.05 min
# 2025-12-07T05:14:05 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T05:14:05 [INFO] Iteration 96 finished in 5.49 min (AUC=0.8473 ± 0.0063, ACC=0.7648, Null_recall=0.7614, WT_recall=0.7683, Null_precision=0.7669, best_AUC=0.8479)
# 2025-12-07T05:14:05 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T05:14:05 [INFO] Iteration 97/100: Optuna trial 97, params={'n_estimators': 900, 'max_depth': 40, 'min_samples_leaf': 2, 'max_features': 'sqrt'}
# 2025-12-07T05:15:40 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T05:15:40 [INFO]    Fold 1/5 finished in 1.59 min
# 2025-12-07T05:17:14 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T05:17:14 [INFO]    Fold 2/5 finished in 1.57 min
# 2025-12-07T05:18:46 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T05:18:46 [INFO]    Fold 3/5 finished in 1.53 min
# 2025-12-07T05:20:19 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T05:20:19 [INFO]    Fold 4/5 finished in 1.55 min
# 2025-12-07T05:21:51 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T05:21:51 [INFO]    Fold 5/5 finished in 1.54 min
# 2025-12-07T05:21:51 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T05:21:51 [INFO] Iteration 97 finished in 7.77 min (AUC=0.8479 ± 0.0062, ACC=0.7663, Null_recall=0.7619, WT_recall=0.7708, Null_precision=0.7689, best_AUC=0.8479)
# 2025-12-07T05:21:51 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T05:21:51 [INFO] Iteration 98/100: Optuna trial 98, params={'n_estimators': 900, 'max_depth': 40, 'min_samples_leaf': 2, 'max_features': 'sqrt'}
# 2025-12-07T05:23:33 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T05:23:33 [INFO]    Fold 1/5 finished in 1.70 min
# 2025-12-07T05:25:07 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T05:25:07 [INFO]    Fold 2/5 finished in 1.56 min
# 2025-12-07T05:26:42 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T05:26:42 [INFO]    Fold 3/5 finished in 1.58 min
# 2025-12-07T05:28:14 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T05:28:14 [INFO]    Fold 4/5 finished in 1.53 min
# 2025-12-07T05:29:47 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T05:29:47 [INFO]    Fold 5/5 finished in 1.55 min
# 2025-12-07T05:29:47 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T05:29:47 [INFO] Iteration 98 finished in 7.93 min (AUC=0.8479 ± 0.0062, ACC=0.7663, Null_recall=0.7619, WT_recall=0.7708, Null_precision=0.7689, best_AUC=0.8479)
# 2025-12-07T05:29:47 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T05:29:47 [INFO] Iteration 99/100: Optuna trial 99, params={'n_estimators': 900, 'max_depth': 40, 'min_samples_leaf': 2, 'max_features': 'log2'}
# 2025-12-07T05:30:19 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T05:30:19 [INFO]    Fold 1/5 finished in 0.53 min
# 2025-12-07T05:30:51 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T05:30:51 [INFO]    Fold 2/5 finished in 0.54 min
# 2025-12-07T05:31:25 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T05:31:25 [INFO]    Fold 3/5 finished in 0.55 min
# 2025-12-07T05:31:57 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T05:31:57 [INFO]    Fold 4/5 finished in 0.54 min
# 2025-12-07T05:32:30 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T05:32:30 [INFO]    Fold 5/5 finished in 0.54 min
# 2025-12-07T05:32:30 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T05:32:30 [INFO] Iteration 99 finished in 2.71 min (AUC=0.8332 ± 0.0073, ACC=0.7513, Null_recall=0.7418, WT_recall=0.7608, Null_precision=0.7564, best_AUC=0.8479)
# 2025-12-07T05:32:30 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T05:32:30 [INFO] Iteration 100/100: Optuna trial 100, params={'n_estimators': 900, 'max_depth': 40, 'min_samples_leaf': 4, 'max_features': 'sqrt'}
# 2025-12-07T05:33:56 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T05:33:56 [INFO]    Fold 1/5 finished in 1.42 min
# 2025-12-07T05:35:20 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T05:35:20 [INFO]    Fold 2/5 finished in 1.41 min
# 2025-12-07T05:36:45 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T05:36:45 [INFO]    Fold 3/5 finished in 1.42 min
# 2025-12-07T05:38:11 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T05:38:11 [INFO]    Fold 4/5 finished in 1.42 min
# 2025-12-07T05:39:36 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T05:39:36 [INFO]    Fold 5/5 finished in 1.43 min
# 2025-12-07T05:39:37 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T05:39:37 [INFO] Iteration 100 finished in 7.11 min (AUC=0.8458 ± 0.0064, ACC=0.7653, Null_recall=0.7596, WT_recall=0.7709, Null_precision=0.7685, best_AUC=0.8479)
# 2025-12-07T05:39:37 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T05:39:37 [INFO] Total search time this session: 360.42 min
# 2025-12-07T05:39:37 [train_12_08_16_45_randomforest_train] INFO: 2025-12-07T05:39:37 [INFO] Best average validation AUC (all completed trials) = 0.8479
# 2025-12-07T05:39:37 [train_12_08_16_45_randomforest_train] INFO: Best hyperparameters (global over study) = {'n_estimators': 900, 'max_depth': 40, 'min_samples_leaf': 2, 'max_features': 'sqrt'}

# %% [markdown]
# ## Retrain model

# %%
# Retrain Random Forest on all training data using best hyperparameters
comb_params = rf_params | best_hp

model = RandomForestClassifier(**comb_params)
model.fit(X, y)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=40,
#                        min_samples_leaf=2, n_estimators=900, n_jobs=-1,
#                        random_state=0)

# %% [markdown]
# ## Shuffle train and validation data

# %%
X_shuf = X.copy()
shuffle_data(X_shuf)

X_test_shuf = X_test.copy()
shuffle_data(X_test_shuf)

# %% [markdown]
# # Save models and model data

# %% [markdown]
# ## Store pre-evaluation split data

# %%
store_pre_evaluation_data(X, y, restdf[meta_cols], "train")
store_pre_evaluation_data(X_shuf, y, restdf[meta_cols], "shuffled_train")

store_pre_evaluation_data(X_test, y_test, testdf[meta_cols], "test")
store_pre_evaluation_data(X_test_shuf, y_test, testdf[meta_cols], "shuffled_test")

# %%
suffix = "_qc" if data_level == "cleaned" else ""

dump(model, f"{data_path}/trained_nf1_model{suffix}.joblib")
dump(le, f"{data_path}/trained_nf1_model_label_encoder{suffix}.joblib")
pd.DataFrame(eval_data).to_parquet(
    f"{data_path}/nf1_model_pre_evaluation_results{suffix}.parquet"
)
